# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good) Exercises</span></div>

# %% [markdown]
# ## Footnotes

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...

# %%
print = 'PRINT'

# %%
print('Hello World')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print('Hello World')
#
# TypeError: 'str' object is not callable

# %% [markdown]
# Oh no, I messed up my print function.[^1]
#
# [^1]: It wasn't me, but I did press the button.

# %%
print('Hello World')
# Out:
# Hello World

# %%
# %%timeit
global squares
squares = [i**2 for i in range(10)]
# Out:
# 1.45 μs ± 200 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# %%timeit
squaresalso = list()
for i in range(10):
    squaresalso.append(i**2)
# Out:
# 769 ns ± 99.7 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
print(squaresalso)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 print(squaresalso)
#
# NameError: name 'squaresalso' is not defined
